# %%
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

# %%
df=pd.read_csv('/Users/shinmirim/Desktop/concrete.csv')

# %%
df.head()
# Out:
#    Cement  BlastFurnaceSlag  FlyAsh  Water  Superplasticizer  CoarseAggregate  \
# 0   540.0               0.0     0.0  162.0               2.5           1040.0
# 1   540.0               0.0     0.0  162.0               2.5           1055.0
# 2   332.5             142.5     0.0  228.0               0.0            932.0
# 3   332.5             142.5     0.0  228.0               0.0            932.0
# 4   198.6             132.4     0.0  192.0               0.0            978.4
#
#    FineAggregate  Age  CompressiveStrength
# 0          676.0   28                79.99
# 1          676.0   28                61.89
# 2          594.0  270                40.27
# 3          594.0  365                41.05
# 4          825.5  360                44.30

# %%
df.drop(columns=['FlyAsh'],inplace=True)

# %%
df[['CoarseAggregate','FineAggregate']].sum()
# Out:
# CoarseAggregate    1002106.5
# FineAggregate       796787.9
# dtype: float64

# %%
df['AggregateSum']=df['CoarseAggregate']+df['FineAggregate']
df
# Out:
#       Cement  BlastFurnaceSlag  Water  Superplasticizer  CoarseAggregate  \
# 0      540.0               0.0  162.0               2.5           1040.0
# 1      540.0               0.0  162.0               2.5           1055.0
# 2      332.5             142.5  228.0               0.0            932.0
# 3      332.5             142.5  228.0               0.0            932.0
# 4      198.6             132.4  192.0               0.0            978.4
# ...      ...               ...    ...               ...              ...
# 1025   276.4             116.0  179.6               8.9            870.1
# 1026   322.2               0.0  196.0              10.4            817.9
# 1027   148.5             139.4  192.7               6.1            892.4
# 1028   159.1             186.7  175.6              11.3            989.6
# 1029   260.9             100.5  200.6               8.6            864.5
#
#       FineAggregate  Age  CompressiveStrength  AggregateSum
# ...

# %%
df
# Out:
#       Cement  BlastFurnaceSlag  Water  Superplasticizer  CoarseAggregate  \
# 0      540.0               0.0  162.0               2.5           1040.0
# 1      540.0               0.0  162.0               2.5           1055.0
# 2      332.5             142.5  228.0               0.0            932.0
# 3      332.5             142.5  228.0               0.0            932.0
# 4      198.6             132.4  192.0               0.0            978.4
# ...      ...               ...    ...               ...              ...
# 1025   276.4             116.0  179.6               8.9            870.1
# 1026   322.2               0.0  196.0              10.4            817.9
# 1027   148.5             139.4  192.7               6.1            892.4
# 1028   159.1             186.7  175.6              11.3            989.6
# 1029   260.9             100.5  200.6               8.6            864.5
#
#       FineAggregate  Age  CompressiveStrength  AggregateSum
# ...
