# %% [markdown]
# # 회귀분석
#
# ### 구할 항목 1 : 신뢰도 (평균평점 * 담긴수 * 긍정확률 평균) = x1
# ### 구할 항목 2 : 반품비율 ( 반품수 / 주문수 ) = x2
#
# #### 이 두가지 항목을 연결지어 하나의 회귀로 돌림 - 관계를 나타내는 그래프 2개가 나와야함 그다음 회귀분석을 돌려 summary로 p값 확인

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\anaconda\lib\site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.15 in c:\anaconda\lib\site-packages (from statsmodels) (1.19.2)
# Requirement already satisfied: scipy>=1.1 in c:\anaconda\lib\site-packages (from statsmodels) (1.5.2)
# Requirement already satisfied: pandas>=0.21 in c:\anaconda\lib\site-packages (from statsmodels) (1.1.3)
# Requirement already satisfied: patsy>=0.5 in c:\anaconda\lib\site-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in c:\anaconda\lib\site-packages (from pandas>=0.21->statsmodels) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\anaconda\lib\site-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: six in c:\anaconda\lib\site-packages (from patsy>=0.5->statsmodels) (1.15.0)

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import warnings
warnings.filterwarnings(action='ignore')

# %%
Regression=pd.read_csv('주문수 환불액 매출액.csv')
Regression.columns
# Out:
# Index(['주문상품명', '주문수', '환불수', '매출액'], dtype='object')

# %%
Regression.dtypes
# Out:
# 주문상품명    object
# 주문수       int64
# 환불수       int64
# 매출액       int64
# dtype: object

# %%
Regression.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2036 entries, 0 to 2035
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주문상품명   2036 non-null   object
#  1   주문수     2036 non-null   int64
#  2   환불수     2036 non-null   int64
#  3   매출액     2036 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 63.8+ KB

# %%
Regre=Regression.dropna(axis=0)
Regre.dtypes
# Out:
# 주문상품명    object
# 주문수       int64
# 환불수       int64
# 매출액       int64
# dtype: object

# %%
Regre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2036 entries, 0 to 2035
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주문상품명   2036 non-null   object
#  1   주문수     2036 non-null   int64
#  2   환불수     2036 non-null   int64
#  3   매출액     2036 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 79.5+ KB

# %%
cnt=pd.read_csv('반품수량다시가져옴.csv')
cnt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주문상품명   57 non-null     object
#  1   반품수량    57 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %%
stat=pd.read_csv('통계서비스_장바구니분석_담긴상품_20210818.csv')
stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   상품명      21 non-null     object
#  1   담긴수      21 non-null     int64
#  2   노출수      21 non-null     int64
#  3   담긴수:노출수  21 non-null     object
#  4   담김율      21 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 968.0+ bytes

# %%
#담김율 : (담긴수 / 노출수) * 100
stat=stat.drop(['담긴수:노출수'],axis=1)
stat.head()
# Out:
#                              상품명  담긴수    노출수   담김율
# 0  [La belle rose]레이니 찰랑 미니 훌원피스  944  38664  2.44
# 1         [La belle rose]페이어 유넥티  825   9366  8.81
# 2    [La belle rose]바넷 브이 끈 롱원피스  481   8296  5.80
# 3                    프리미 여리핏 가디건  472  12361  3.82
# 4   [La belle rose]로제 스퀘어 미니훌원피스  430  38078  1.13

# %%
stat.rename(columns={'상품명':'주문상품명'},inplace=True)
stat.head()
# Out:
#                            주문상품명  담긴수    노출수   담김율
# 0  [La belle rose]레이니 찰랑 미니 훌원피스  944  38664  2.44
# 1         [La belle rose]페이어 유넥티  825   9366  8.81
# 2    [La belle rose]바넷 브이 끈 롱원피스  481   8296  5.80
# 3                    프리미 여리핏 가디건  472  12361  3.82
# 4   [La belle rose]로제 스퀘어 미니훌원피스  430  38078  1.13

# %%
cnt.head()
# Out:
#                            주문상품명  반품수량
# 0   [1+1] 기획특가♥웰데이 베이직셔츠(썸머.ver)     1
# 1       [DAYONE LABEL]빈티지 중청 숏데님     1
# 2    [DAYONE LABEL]슬림 세미부츠컷 데님팬츠     1
# 3  [DAYONE LABEL]아이시블루 썸머 하이스키니진     1
# 4        [DAYONE LABEL]쫀쫀 연청 숏데님     2

# %%
#Regre, stat, cnt를 Regre의 주문상품명을 기준으로 합치기
result=pd.merge(Regre,stat,how='outer',on='주문상품명')
result
# Out:
#                               주문상품명    주문수   환불수        매출액      담긴수  \
# 0     [La belle rose]레이니 찰랑 미니 훌원피스  212.0  34.0  5304400.0    944.0
# 1     [La belle rose]레이니 찰랑 미니 훌원피스  122.0  16.0  3158800.0    944.0
# 2            [La belle rose]페이어 유넥티  139.0  20.0  1404200.0    825.0
# 3            [La belle rose]페이어 유넥티   80.0  12.0   802400.0    825.0
# 4            [La belle rose]페이어 유넥티   64.0  14.0   590000.0    825.0
# ...                             ...    ...   ...        ...      ...
# 2032                  루세 시스루 셔링블라우스    0.0   1.0   -32500.0      NaN
# 2033                코노 셔츠원피스(벨트set)    0.0   1.0   -23000.0      NaN
# 2034                세이린 롱원피스(벨트set)    1.0   2.0   -48900.0      NaN
# 2035                      보브 프릴블라우스    0.0   3.0  -123000.0      NaN
# 2036                             합계    NaN   NaN        NaN  27269.0
#
#            노출수   담김율
# 0      38664.0  2.44
# 1      38664.0  2.44
# 2       9366.0  8.81
# 3       9366.0  8.81
# 4       9366.0  8.81
# ...        ...   ...
# 2032       NaN   NaN
# 2033       NaN   NaN
# 2034       NaN   NaN
# 2035       NaN   NaN
# 2036  746105.0  3.65
#
# [2037 rows x 7 columns]

# %%
result.to_excel('result1.xlsx',index=False)

# %%
Regres=pd.merge(result,cnt,how='outer',on='주문상품명')
Regres
# Out:
#                               주문상품명    주문수   환불수        매출액      담긴수  \
# 0     [La belle rose]레이니 찰랑 미니 훌원피스  212.0  34.0  5304400.0    944.0
# 1     [La belle rose]레이니 찰랑 미니 훌원피스  122.0  16.0  3158800.0    944.0
# 2            [La belle rose]페이어 유넥티  139.0  20.0  1404200.0    825.0
# 3            [La belle rose]페이어 유넥티   80.0  12.0   802400.0    825.0
# 4            [La belle rose]페이어 유넥티   64.0  14.0   590000.0    825.0
# ...                             ...    ...   ...        ...      ...
# 2033                코노 셔츠원피스(벨트set)    0.0   1.0   -23000.0      NaN
# 2034                세이린 롱원피스(벨트set)    1.0   2.0   -48900.0      NaN
# 2035                      보브 프릴블라우스    0.0   3.0  -123000.0      NaN
# 2036                             합계    NaN   NaN        NaN  27269.0
# 2037                            총합계    NaN   NaN        NaN      NaN
#
#            노출수   담김율  반품수량
# 0      38664.0  2.44   3.0
# 1      38664.0  2.44   3.0
# 2       9366.0  8.81   3.0
# 3       9366.0  8.81   3.0
# 4       9366.0  8.81   3.0
# ...        ...   ...   ...
# 2033       NaN   NaN   NaN
# 2034       NaN   NaN   NaN
# 2035       NaN   NaN   NaN
# 2036  746105.0  3.65   NaN
# 2037       NaN   NaN  77.0
#
# [2038 rows x 8 columns]

# %%
Regres.shape
# Out:
# (2038, 8)

# %%
Regres.to_excel('Regres.xlsx',index=False)

# %%
Regres=Regres.dropna(axis=0)
Regres.shape
# Out:
# (35, 8)

# %%
Regres
# Out:
#                                        주문상품명    주문수   환불수        매출액    담긴수  \
# 0              [La belle rose]레이니 찰랑 미니 훌원피스  212.0  34.0  5304400.0  944.0
# 1              [La belle rose]레이니 찰랑 미니 훌원피스  122.0  16.0  3158800.0  944.0
# 2                     [La belle rose]페이어 유넥티  139.0  20.0  1404200.0  825.0
# 3                     [La belle rose]페이어 유넥티   80.0  12.0   802400.0  825.0
# 4                     [La belle rose]페이어 유넥티   64.0  14.0   590000.0  825.0
# 5                     [La belle rose]페이어 유넥티   40.0   7.0   389400.0  825.0
# 6                     [La belle rose]페이어 유넥티   28.0   3.0   295000.0  825.0
# 7                     [La belle rose]페이어 유넥티    4.0   2.0    23600.0  825.0
# 12                             드민 플라워 쉬폰롱원피스  119.0  29.0  4302000.0  375.0
# 13                             드민 플라워 쉬폰롱원피스    2.0   0.0    95600.0  375.0
# 14               [La belle rose]바넷 브이 끈 롱원피스   80.0  14.0  1306800.0  481.0
# 15               [La belle rose]바넷 브이 끈 롱원피스   67.0  11.0  1108800.0  481.0
# 16               [La belle rose]바넷 브이 끈 롱원피스   31.0   6.0   495000.0  481.0
# 48                [La belle rose]프레인 퍼프 스퀘어티   48.0   8.0   752000.0  428.0
# 49                [La belle rose]프레인 퍼프 스퀘어티   39.0   7.0   601600.0  428.0
# 50                [La belle rose]프레인 퍼프 스퀘어티   33.0   4.0   545200.0  428.0
# 51                [La belle rose]프레인 퍼프 스퀘어티   27.0   4.0   432400.0  428.0
# 52              [1+1] 기획특가♥웰데이 베이직셔츠(썸머.ver)   47.0   8.0   702000.0  290.0
# 53              [1+1] 기획특가♥웰데이 베이직셔츠(썸머.ver)   22.0   4.0   324000.0  290.0
# 54              [1+1] 기획특가♥웰데이 베이직셔츠(썸머.ver)   17.0   1.0   288000.0  290.0
# 55              [1+1] 기획특가♥웰데이 베이직셔츠(썸머.ver)   12.0   0.0   216000.0  290.0
# 56              [1+1] 기획특가♥웰데이 베이직셔츠(썸머.ver)   12.0   3.0   162000.0  290.0
# 66                   [La belle rose]이든 롱랩원피스   43.0   8.0   693000.0  223.0
# 67                   [La belle rose]이든 롱랩원피스   29.0   5.0   475200.0  223.0
# 79                [La belle rose]드로우 셔링 롱원피스   44.0  14.0  1410000.0  297.0
# 80                [La belle rose]드로우 셔링 롱원피스   39.0  13.0  1222000.0  297.0
# 81                [La belle rose]드로우 셔링 롱원피스   20.0   7.0   611000.0  297.0
# 111  [La belle rose]딘트 체크 스퀘어원피스(+3cm기장추가옵션)   24.0   1.0   920000.0  278.0
# 112  [La belle rose]딘트 체크 스퀘어원피스(+3cm기장추가옵션)   22.0   7.0   600000.0  278.0
# 113  [La belle rose]딘트 체크 스퀘어원피스(+3cm기장추가옵션)   13.0   0.0   520000.0  278.0
# 114  [La belle rose]딘트 체크 스퀘어원피스(+3cm기장추가옵션)   14.0   5.0   360000.0  278.0
# 115  [La belle rose]딘트 체크 스퀘어원피스(+3cm기장추가옵션)   10.0   3.0   280000.0  278.0
# 116  [La belle rose]딘트 체크 스퀘어원피스(+3cm기장추가옵션)   10.0   4.0   240000.0  278.0
# 117  [La belle rose]딘트 체크 스퀘어원피스(+3cm기장추가옵션)    9.0   3.0   240000.0  278.0
# 118  [La belle rose]딘트 체크 스퀘어원피스(+3cm기장추가옵션)    4.0   1.0   120000.0  278.0
#
#          노출수   담김율  반품수량
# 0    38664.0  2.44   3.0
# 1    38664.0  2.44   3.0
# 2     9366.0  8.81   3.0
# 3     9366.0  8.81   3.0
# 4     9366.0  8.81   3.0
# 5     9366.0  8.81   3.0
# 6     9366.0  8.81   3.0
# 7     9366.0  8.81   3.0
# 12   29077.0  1.29   3.0
# 13   29077.0  1.29   3.0
# 14    8296.0  5.80   1.0
# 15    8296.0  5.80   1.0
# 16    8296.0  5.80   1.0
# 48    8723.0  4.91   2.0
# 49    8723.0  4.91   2.0
# 50    8723.0  4.91   2.0
# 51    8723.0  4.91   2.0
# 52    3821.0  7.59   1.0
# 53    3821.0  7.59   1.0
# 54    3821.0  7.59   1.0
# 55    3821.0  7.59   1.0
# 56    3821.0  7.59   1.0
# 66    2840.0  7.85   2.0
# 67    2840.0  7.85   2.0
# 79   20314.0  1.46   2.0
# 80   20314.0  1.46   2.0
# 81   20314.0  1.46   2.0
# 111  18379.0  1.51   1.0
# 112  18379.0  1.51   1.0
# 113  18379.0  1.51   1.0
# 114  18379.0  1.51   1.0
# 115  18379.0  1.51   1.0
# 116  18379.0  1.51   1.0
# 117  18379.0  1.51   1.0
# 118  18379.0  1.51   1.0

# %%
Regres.columns
# Out:
# Index(['주문상품명', '주문수', '환불수', '매출액', '담긴수', '노출수', '담김율', '반품수량'], dtype='object')

# %% [markdown]
# ### 구할 항목 1 : 신뢰도 (평균평점 * 담긴수 * 긍정확률 평균) = x1
# ### 구할 항목 2 : 반품비율 ( 반품수 / 주문수 ) = x2

# %% [markdown]
# ### X2 시행

# %%
Regres['반품비율']=Regres['반품수량']/Regres['주문수']
Regres.head()
# Out:
#                            주문상품명    주문수   환불수        매출액    담긴수      노출수  \
# 0  [La belle rose]레이니 찰랑 미니 훌원피스  212.0  34.0  5304400.0  944.0  38664.0
# 1  [La belle rose]레이니 찰랑 미니 훌원피스  122.0  16.0  3158800.0  944.0  38664.0
# 2         [La belle rose]페이어 유넥티  139.0  20.0  1404200.0  825.0   9366.0
# 3         [La belle rose]페이어 유넥티   80.0  12.0   802400.0  825.0   9366.0
# 4         [La belle rose]페이어 유넥티   64.0  14.0   590000.0  825.0   9366.0
#
#     담김율  반품수량      반품비율
# 0  2.44   3.0  0.014151
# 1  2.44   3.0  0.024590
# 2  8.81   3.0  0.021583
# 3  8.81   3.0  0.037500
# 4  8.81   3.0  0.046875

# %%
import seaborn as sns
from matplotlib import font_manager,rc
font_path='C:\Windows\Fonts/malgun.ttf'
font=font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font)

# %%
sns.regplot(Regres['매출액'],Regres['반품비율'],lowess=True)
# Out:
# <AxesSubplot:xlabel='매출액', ylabel='반품비율'>

# %% [markdown]
# ### X1 수행

# %%
Regres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 118
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주문상품명   35 non-null     object
#  1   주문수     35 non-null     float64
#  2   환불수     35 non-null     float64
#  3   매출액     35 non-null     float64
#  4   담긴수     35 non-null     float64
#  5   노출수     35 non-null     float64
#  6   담김율     35 non-null     float64
#  7   반품수량    35 non-null     float64
#  8   반품비율    35 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 2.7+ KB

# %%
Regres.to_excel('X2그래프.xlsx',index=False)

# %%
rg=pd.read_excel('X2반영.xlsx')
rg.head()
# Out:
#                            주문상품명  주문수  환불수      매출액  담긴수    노출수   담김율  반품수량  \
# 0  [La belle rose]레이니 찰랑 미니 훌원피스  212   34  5304400  944  38664  2.44     3
# 1  [La belle rose]레이니 찰랑 미니 훌원피스  122   16  3158800  944  38664  2.44     3
# 2         [La belle rose]페이어 유넥티  139   20  1404200  825   9366  8.81     3
# 3         [La belle rose]페이어 유넥티   80   12   802400  825   9366  8.81     3
# 4         [La belle rose]페이어 유넥티   64   14   590000  825   9366  8.81     3
#
#        반품비율      평균평점   긍정확률 평균
# 0  0.014151  4.818182  0.935579
# 1  0.024590  4.818182  0.935579
# 2  0.021583  4.637306  0.826701
# 3  0.037500  4.637306  0.826701
# 4  0.046875  4.637306  0.826701

# %%
rg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   주문상품명    35 non-null     object
#  1   주문수      35 non-null     int64
#  2   환불수      35 non-null     int64
#  3   매출액      35 non-null     int64
#  4   담긴수      35 non-null     int64
#  5   노출수      35 non-null     int64
#  6   담김율      35 non-null     float64
#  7   반품수량     35 non-null     int64
#  8   반품비율     35 non-null     float64
#  9   평균평점     35 non-null     float64
#  10  긍정확률 평균  35 non-null     float64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
#신뢰도 (평균평점 * 담긴수 * 긍정확률 평균) = x1
rg['신뢰도']=rg['평균평점']*rg['담긴수']*rg['긍정확률 평균']
rg.head()
# Out:
#                            주문상품명  주문수  환불수      매출액  담긴수    노출수   담김율  반품수량  \
# 0  [La belle rose]레이니 찰랑 미니 훌원피스  212   34  5304400  944  38664  2.44     3
# 1  [La belle rose]레이니 찰랑 미니 훌원피스  122   16  3158800  944  38664  2.44     3
# 2         [La belle rose]페이어 유넥티  139   20  1404200  825   9366  8.81     3
# 3         [La belle rose]페이어 유넥티   80   12   802400  825   9366  8.81     3
# 4         [La belle rose]페이어 유넥티   64   14   590000  825   9366  8.81     3
#
#        반품비율      평균평점   긍정확률 평균          신뢰도
# 0  0.014151  4.818182  0.935579  4255.354965
# 1  0.024590  4.818182  0.935579  4255.354965
# 2  0.021583  4.637306  0.826701  3162.772001
# 3  0.037500  4.637306  0.826701  3162.772001
# 4  0.046875  4.637306  0.826701  3162.772001

# %%
sns.regplot('매출액','신뢰도',lowess=True,data=rg)
# Out:
# <AxesSubplot:xlabel='매출액', ylabel='신뢰도'>

# %%
x_data=rg[['신뢰도','반품비율']] #X1,X2
target=rg[['매출액']] #Y1

# %%
x_data1=sm.add_constant(x_data,has_constant='add')

# %%
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    매출액   R-squared:                       0.314
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     7.335
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):            0.00239
# Time:                        21:43:29   Log-Likelihood:                -530.65
# No. Observations:                  35   AIC:                             1067.
# Df Residuals:                      32   BIC:                             1072.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.511e+04   3.56e+05     -0.155      0.878    -7.8e+05     6.7e+05
# 신뢰도          587.4577    169.300      3.470      0.002     242.604     932.311
# 반품비율       -1.094e+06   6.19e+05     -1.769      0.086   -2.35e+06    1.66e+05
# ==============================================================================
# Omnibus:                       26.945   Durbin-Watson:                   1.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.100
# Skew:                           1.881   Prob(JB):                     2.95e-12
# Kurtosis:                       7.718   Cond. No.                     7.85e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x_data=rg[['신뢰도']] #X2
target=rg[['매출액']] #Y1

# %%
x_data2=sm.add_constant(x_data,has_constant='add')

# %%
multi_model = sm.OLS(target, x_data2)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    매출액   R-squared:                       0.247
# Model:                            OLS   Adj. R-squared:                  0.225
# Method:                 Least Squares   F-statistic:                     10.84
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):            0.00237
# Time:                        21:58:20   Log-Likelihood:                -532.28
# No. Observations:                  35   AIC:                             1069.
# Df Residuals:                      33   BIC:                             1072.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.658e+05   3.61e+05     -0.459      0.649   -9.01e+05     5.7e+05
# 신뢰도          574.6571    174.513      3.293      0.002     219.607     929.708
# ==============================================================================
# Omnibus:                       25.760   Durbin-Watson:                   1.618
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.293
# Skew:                           1.800   Prob(JB):                     1.98e-11
# Kurtosis:                       7.566   Cond. No.                     4.42e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.42e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x_data=rg[['반품비율']] #X2
target=rg[['매출액']] #Y1
x_data3=sm.add_constant(x_data,has_constant='add')
multi_model = sm.OLS(target, x_data3)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    매출액   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     1.971
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):              0.170
# Time:                        21:59:07   Log-Likelihood:                -536.24
# No. Observations:                  35   AIC:                             1076.
# Df Residuals:                      33   BIC:                             1080.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.008e+06   2.09e+05      4.823      0.000    5.83e+05    1.43e+06
# 반품비율       -1.002e+06   7.14e+05     -1.404      0.170   -2.45e+06     4.5e+05
# ==============================================================================
# Omnibus:                       39.601   Durbin-Watson:                   0.737
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              113.154
# Skew:                           2.723   Prob(JB):                     2.68e-25
# Kurtosis:                       9.924   Cond. No.                         3.82
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
