# %%
pip install pororo

# %%
from google.colab import files
myfile=files.upload()
# Out:
#      <input type="file" id="files-4e533df1-6b47-44ba-a443-635a13979cf3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e533df1-6b47-44ba-a443-635a13979cf3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Reviewata_clean.xlsx to Reviewata_clean (1).xlsx

# %%
import io
import pandas as pd
import numpy as np

# %%
review=pd.read_excel(io.BytesIO(myfile['Reviewata_clean.xlsx']))
review1=review.iloc[:50]
review1.head()
# Out:
#    Unnamed: 0        상품명  평점                                               리뷰내용
# 0       13699  라벨르 베이직셔츠   5  두께도 적당하고 디자인 색감 다 맘에 들어오 \n가격도 저렴하고 잘산것같아요!! 담...
# 1       13778  라벨르 베이직셔츠   4  딱 기본 셔츠하게 좋아요! 부들부들한데 너무 빳빳한 소재도 아닌게 딱 여리해보이고 ...
# 2       13970  라벨르 베이직셔츠   5                       청바지에도 어울리고 슬랙스에도 어울리고 좋아요 !!
# 3       14169  라벨르 베이직셔츠   5  청바지에 입어도 예쁘고 치마랑 입어도 예뻐요!! 카라가 커서 기본템이어도 마냥 무난...
# 4       14903  라벨르 베이직셔츠   4  보들보들하니 딱 좋아용 ㅎ 소재 특성상 주름은 어쩔수 없지만 너무 예뻐요 자켓이랑 ...

# %%
pip install pymysql
# Out:
# ...
#      |████████████████████████████████| 43 kB 2.1 MB/s
# ...

# %%
pip install utils

# %%
# import time
# import pymysql
# import configparser
# from datetime import datetime
from pororo import Pororo

# %%
sa = Pororo(task="sentiment", model="brainbert.base.ko.shopping", lang="ko")

# %%
sa('배송이 버트 학습시키는 것 만큼 느리네요')
# Out:
# 'Negative'

# %%
sa("배송이 경량화되었는지 빠르네요")
# Out:
# 'Positive'

# %%
sa('사이즈보다 조금 크게 나왔나요?ㅠㅠ 색깔은 이뻐요',show_probs=True)
# Out:
# {'negative': 0.6971524953842163, 'positive': 0.3028474748134613}

# %% [markdown]
# # Pororo를 바탕으로 각 문장마다 어느정도으 확률로 긍정, 부정을 나타내는지 for문을 통해서 나타낸다.

# %%
print(review['리뷰내용'].iloc[5000])
sa(review['리뷰내용'].iloc[5000],show_probs=True)
# Out:
# 야들야들?한 재질이고 여리여리하게 입을 수 있어요
# {'negative': 0.034836333245038986, 'positive': 0.9651636481285095}

# %%
import pandas
print(pandas.__version__)
# Out:
# 1.1.5

# %%
import pandas as pd 
from pandas import Series, DataFrame
import numpy as np

# %%
sentence_to_SA=Series([review.리뷰내용])
sentence_to_SA
# Out:
# 0    0        두께도 적당하고 디자인 색감 다 맘에 들어오 \n가격도 저렴하고 잘...
# dtype: object

# %%
sa = Pororo(task="sentiment", model="brainbert.base.ko.shopping", lang="ko")
print("pororo load done",str(review))
# Out:
# pororo load done        Unnamed: 0  ...                                               리뷰내용
# 0           13699  ...  두께도 적당하고 디자인 색감 다 맘에 들어오 \n가격도 저렴하고 잘산것같아요!! 담...
# 1           13778  ...  딱 기본 셔츠하게 좋아요! 부들부들한데 너무 빳빳한 소재도 아닌게 딱 여리해보이고 ...
# 2           13970  ...                       청바지에도 어울리고 슬랙스에도 어울리고 좋아요 !!
# 3           14169  ...  청바지에 입어도 예쁘고 치마랑 입어도 예뻐요!! 카라가 커서 기본템이어도 마냥 무난...
# 4           14903  ...  보들보들하니 딱 좋아용 ㅎ 소재 특성상 주름은 어쩔수 없지만 너무 예뻐요 자켓이랑 ...
# ...           ...  ...                                                ...
# 57359       52139  ...           레깅스 말고도 편하게 입고 다닐만한 팬츠 찾고 있었어욤 \n대만족 입니당
# 57360       53947  ...  착용감이 좋고 핏이 이뻐요 강추합니다\n\n\n(2020-09-22 22:17:22...
# 57361       55343  ...               편하게 입기좋아요 티랑 같이구매했는데 딱이에요 편하고 핏도이뻐요
# 57362       55472  ...  편하게입고잇습니다~\n\n(2020-08-29 22:49:28 에 등록된 네이버 페...
# 57363       55476  ...  편해서 자주입고잇습니다\n\n(2020-08-29 22:51:14 에 등록된 네이버...
#
# [57364 rows x 4 columns]

# %%
for r in range(0,len(review1)):
 print(sa(df[r]))
# Out:
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Positive

# %%
a=[]
b=[]
for r in range(0,len(review1)):
  result_dict=sa(df[r],show_probs=True)

  neg_prob=result_dict['negative'] 
  pos_prob=result_dict['positive']

  a.append(neg_prob)
  a
  b.append(pos_prob)
  b

# %%
b
# Out:
# [0.993376612663269,
#  0.9934001564979553,
#  0.9924430847167969,
#  0.9935683608055115,
#  0.9931987524032593,
#  0.993376612663269,
#  0.9934001564979553,
#  0.9924430847167969,
#  0.9935683608055115,
#  0.9931987524032593,
#  0.6044487953186035,
#  0.9876890182495117,
#  0.9934177994728088,
#  0.9934151768684387,
#  0.9926367998123169,
#  0.9900695085525513,
#  0.9915883541107178,
#  0.9922176599502563,
#  0.9906260967254639,
#  0.9894850850105286,
#  0.9717381000518799,
#  0.9936161041259766,
#  0.9934090971946716,
#  0.992375373840332,
#  0.9916319251060486,
#  0.9937911033630371,
#  0.9818590879440308,
#  0.9933279156684875,
#  0.9924687743186951,
#  0.9924545884132385,
#  0.9931281805038452,
#  0.9929840564727783,
#  0.9748150110244751,
#  0.9924845099449158,
#  0.9801993370056152,
#  0.9867525100708008,
#  0.3478889465332031,
#  0.9928600788116455,
#  0.993624746799469,
#  0.9914572834968567,
#  0.9881664514541626,
#  0.9921937584877014,
#  0.9927233457565308,
# ...

# %%
review1['긍정확률']=b
review1['부정확률']=a
review1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Unnamed: 0        상품명  ...      긍정확률      부정확률
# 0       13699  라벨르 베이직셔츠  ...  0.993377  0.006623
# 1       13778  라벨르 베이직셔츠  ...  0.993400  0.006600
# 2       13970  라벨르 베이직셔츠  ...  0.992443  0.007557
# ...

# %%
review1['최종판단']=review1.apply(lambda x : 'Positive' if x['긍정확률']>x['부정확률'] else 'Negative',axis=1 )
review1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    Unnamed: 0        상품명  평점  ...      긍정확률      부정확률      최종판단
# 0       13699  라벨르 베이직셔츠   5  ...  0.993377  0.006623  Positive
# 1       13778  라벨르 베이직셔츠   4  ...  0.993400  0.006600  Positive
# 2       13970  라벨르 베이직셔츠   5  ...  0.992443  0.007557  Positive
# 3       14169  라벨르 베이직셔츠   5  ...  0.993568  0.006432  Positive
# 4       14903  라벨르 베이직셔츠   4  ...  0.993199  0.006801  Positive
#
# [5 rows x 7 columns]

# %%
review=pd.read_excel(io.BytesIO(myfile['Reviewata_clean.xlsx']))

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57364 entries, 0 to 57363
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  57364 non-null  int64
#  1   상품명         57364 non-null  object
#  2   평점          57364 non-null  int64
#  3   리뷰내용        57363 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 1.8+ MB

# %%
review.drop(index=[2487],inplace=True)

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57363 entries, 0 to 57363
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  57363 non-null  int64
#  1   상품명         57363 non-null  object
#  2   평점          57363 non-null  int64
#  3   리뷰내용        57363 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 2.2+ MB

# %%
a=[]
b=[]
for r in range(0,len(review)):
  result_dict=sa(review.iloc[r,3],show_probs=True)

  neg_prob=result_dict['negative'] 
  pos_prob=result_dict['positive']

  a.append(neg_prob)
  b.append(pos_prob)

# %%
review['긍정확률']=b
review['부정확률']=a

review['최종판단']=review1.apply(lambda x : 'Positive' if x['긍정확률']>x['부정확률'] else 'Negative',axis=1 )
review.head()
# Out:
#    Unnamed: 0        상품명  평점  ...      긍정확률      부정확률      최종판단
# 0       13699  라벨르 베이직셔츠   5  ...  0.993377  0.006623  Positive
# 1       13778  라벨르 베이직셔츠   4  ...  0.993400  0.006600  Positive
# 2       13970  라벨르 베이직셔츠   5  ...  0.992443  0.007557  Positive
# 3       14169  라벨르 베이직셔츠   5  ...  0.993568  0.006432  Positive
# 4       14903  라벨르 베이직셔츠   4  ...  0.993199  0.006801  Positive
#
# [5 rows x 7 columns]

# %%
review.to_excel('reviewdata.xlsx', index=False)

# %%
 all_sent_result=[]

for idx,row in review.iterrows():
  sentence_to_SA=Series([review.리뷰내용])
  try:
    if sentence_to_SA == '': #문장이 적혀있지 않으면
      pass

    else:
      result_dict=sa(sentence_to_SA,show_probs=True)

      neg_prob= result_dict['negative']
      pos_prob= result_dict['positive']

      semtiment_label=classify_sentiment_result(neg_prob,pos_prob)
  

      sent_sa_result = ['상품명', '평점', '리뷰내용','pos_prob', 'neg_prob']
      all_sent_result.append(result_dict)  # append to upper level list


  except:
        pass

all_sa_result_df = pd.DataFrame(review, columns=['상품명', '평점', '리뷰내용','pos_prob', 'neg_prob'])




all_sa_result_df.to_csv('/content/drive/My Drive/mirim/sa_result_210716_'+'.xlsx', encoding='utf-8-sig')
3
print()
print("File name:", '/content/drive/My Drive/mirim/sa_result_210716_'+'.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-39a4d069bef0> in <module>()
#       2
#       3 for idx,row in review.iterrows():
# ----> 4   sentence_to_SA=row.review['리뷰내용']
#       5   try:
#       6     if sentence_to_SA == '': #문장이 적혀있지 않으면
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'review'

# %%
all_sa_result_df
# Out:
# Empty DataFrame
# Columns: [상품명, 평점, 리뷰내용, pos_prob, neg_prob]
# Index: []

# %%
 all_sent_result
# Out:
# []

# %%
pip install --upgrade google-api-python-client
# Out:
# ...
#      |████████████████████████████████| 7.2 MB 11.9 MB/s
# ...
#   Attempting uninstall: google-auth-httplib2
#     Found existing installation: google-auth-httplib2 0.0.4
#     Uninstalling google-auth-httplib2-0.0.4:
#       Successfully uninstalled google-auth-httplib2-0.0.4
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 1.12.8
#     Uninstalling google-api-python-client-1.12.8:
#       Successfully uninstalled google-api-python-client-1.12.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# earthengine-api 0.1.272 requires google-api-python-client<2,>=1.12.1, but you have google-api-python-client 2.15.0 which is incompatible.
# ...

# %%
pip install google

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive
# Out:
# MyDrive

# %%
cd /content/drive/My Drive/mirim
# Out:
# /content/drive/My Drive/mirim

# %%
def classify_sentiment_result(neg_prob, pos_prob):
    if pos_prob > neg_prob:
        bi_result = 'Positive'
    else:
        bi_result = 'Negative'

    return bi_result
